        3.479183959855502e-10, 2.6113493063976004e-10, 1.9347625047494855e-10, 1.4074331141301449e-10,
        1.0005782180070051e-10, 6.91413699530009e-11, 5.295891884384561e-10, 3.975304150810144e-10, 
        2.987114067339546e-10, 2.219291260734052e-10, 1.6210105151045288e-10, 1.1582244303314377e-10,
        8.048779409029554e-11, 5.635450007349884e-10, 4.2289625088369597e-10, 3.1791969659417945e-10,
        2.3647194415499193e-10, 1.7301734172139806e-10, 1.2388095459960737e-10, 8.628904053697958e-11,
        8.024386930853256e-10, 5.968081264661888e-10, 4.474731257815997e-10, 3.3414591098709614e-10,
        2.4694212930368345e-10, 1.794998867581298e-10, 1.274397788472041e-10, 1.0224352087332016e-9,
        7.554466947944404e-10, 5.645171087653249e-10, 4.216659898970058e-10, 3.1281637537028347e-10,
        2.2895114458204562e-10, 1.640719766720905e-10, 1.1382220294899391e-9, 8.387861249704263e-10,
        6.258987584088154e-10, 4.67499268974361e-10, 3.472843060542954e-10, 2.5482091760428603e-10,
        1.83243911838578e-10, 1.4672741334192307e-9, 1.0690968273413907e-9, 7.908482303851548e-10,
        5.87869081316547e-10, 4.366008256568429e-10, 3.2171184547343415e-10, 2.3324936061088466e-10,
        1.742384909196414e-9, 1.2618271273413623e-9, 9.28493379680592e-10, 6.879229286675326e-10,
        5.105164951471957e-10, 3.7683085424495467e-10, 2.743009694399612e-10, 2.1966056168624566e-9,
        1.5759620714062975e-9, 1.1488703422464944e-9, 8.45308865271298e-10, 6.250400284457753e-10,
        4.6137874178715616e-10, 3.370329466389857e-10]
ells = [359,  462,  593,  762,  979, 1257, 1615]

# %%
figure, axis = plt.subplots(4, 4, figsize=(16,16))
l = 0
idx = [7*i for i in range(0, 11)] 
for i in range(0,4):
    for j in range(0,4):
        if j >= i:
            axis[i, j].errorbar(ells, data[idx[l]:idx[l+1]], yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
            axis[i, j].plot(ells, theory[idx[l]:idx[l+1]], 'bo-', label="LimberJack")
            axis[i, j].set_title("HSC_wl__{}{}".format(i,j))
            l += 1
        else:
            figure.delaxes(axis[i][j])
plt.legend()
plt.show()

# %%
figure, axis = plt.subplots(4, 4, figsize=(16,16))
l = 0
for i in range(0,4):
    for j in range(0,4):
        if j >= i:
            t1, t2 = pairs[l][0], pairs[l][1]
            axis[i, j].errorbar(files["ls_{}_{}".format(t1, t2)], 
                         data[idx[l]:idx[l+1]], 
                         yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
            axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
                            cls_m[idx[l]:idx[l+1]], 'bo-', label="jaime")
            axis[i, j].fill_between(files["ls_{}_{}".format(t1, t2)],
                            (cls_m+cls_s)[idx[l]:idx[l+1]],
                            (cls_m-cls_s)[idx[l]:idx[l+1]],
                            color="b", alpha=.5)
            #axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
            #                cls_carlos[idx[l]:idx[l+1]],
            #                "ro-", label="carlos")
            axis[i, j].set_title("{}_{}".format(t1,t2))
            l += 1
plt.legend()
plt.show()
print(l)
